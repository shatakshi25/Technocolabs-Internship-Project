# %%
import pandas as pd

# %%
df = pd.read_excel("/content/drive/My Drive/Technocolabs project/default_of_credit_card_clients.xls")
df
# Out:
#                   ID  LIMIT_BAL  ...  PAY_AMT6  default payment next month
# 0      798fc410-45c1      20000  ...         0                           1
# 1      8a8c8f3b-8eb4     120000  ...      2000                           1
# 2      85698822-43f5      90000  ...      5000                           0
# 3      0737c11b-be42      50000  ...      1000                           0
# 4      3b7f77cc-dbc0      50000  ...       679                           0
# ...              ...        ...  ...       ...                         ...
# 29995  ecff42d0-bdc6     220000  ...      1000                           0
# 29996  99d1fa0e-222b     150000  ...         0                           0
# 29997  95cdd3e7-4f24      30000  ...      3100                           1
# 29998  00d03f02-04cd      80000  ...      1804                           1
# 29999  15d69f9f-5ad3      50000  ...      1000                           1
#
# [30000 rows x 25 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df['ID'].nunique()
# Out:
# 29687

# %%
df.head()
# Out:
#               ID  LIMIT_BAL  ...  PAY_AMT6  default payment next month
# 0  798fc410-45c1      20000  ...         0                           1
# 1  8a8c8f3b-8eb4     120000  ...      2000                           1
# 2  85698822-43f5      90000  ...      5000                           0
# 3  0737c11b-be42      50000  ...      1000                           0
# 4  3b7f77cc-dbc0      50000  ...       679                           0
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (30000, 25)

# %%
id_counts = df['ID'].value_counts()
id_counts.head()
# Out:
# ff619017-560f    2
# e7f574b9-0581    2
# 30729bb5-55d7    2
# 0d624cb8-e5f8    2
# 5b8dce34-2ded    2
# Name: ID, dtype: int64

# %%
id_counts.value_counts()
# Out:
# 1    29374
# 2      313
# Name: ID, dtype: int64

# %%
import numpy as np

# %%
np.random.seed(seed=24)

# %%
random_integers = np.random.randint(low=1,high=5,size=100)

# %%
is_equal_to_3 = random_integers == 3

# %%
is_equal_to_3[:5]
# Out:
# array([ True, False, False, False, False])

# %%
sum(is_equal_to_3)
# Out:
# 22

# %%
random_integers[is_equal_to_3]
# Out:
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3])

# %%
id_counts = df['ID'].value_counts()
dupe_mask = id_counts == 2
dupe_mask[0:5]
# Out:
# ff619017-560f    True
# e7f574b9-0581    True
# 30729bb5-55d7    True
# 0d624cb8-e5f8    True
# 5b8dce34-2ded    True
# Name: ID, dtype: bool

# %%
dupe_ids = id_counts.index[dupe_mask]
dupe_ids = list(dupe_ids)
len(dupe_ids)
# Out:
# 313

# %%
df.loc[df['ID'].isin(dupe_ids[0:3]),:].head(10)
# Out:
#                   ID  LIMIT_BAL  ...  PAY_AMT6  default payment next month
# 12091  ff619017-560f     160000  ...     10284                           0
# 12191  ff619017-560f          0  ...         0                           0
# 15260  e7f574b9-0581     290000  ...      4280                           0
# 15360  e7f574b9-0581          0  ...         0                           0
# 27333  30729bb5-55d7     110000  ...         0                           0
# 27433  30729bb5-55d7          0  ...         0                           0
#
# [6 rows x 25 columns]

# %%
df_zero_mask = df == 0

# %%
feature_zero_mask = df_zero_mask.iloc[:,1:].all(axis=1)
sum(feature_zero_mask)
# Out:
# 315

# %%
df_clean_1 = df.loc[~feature_zero_mask,:].copy()

# %%
df_clean_1['ID'].nunique()
# Out:
# 29685

# %%
valid_pay_1_mask = df_clean_1['PAY_1'] != 'Not available'
valid_pay_1_mask[0:5]
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: PAY_1, dtype: bool

# %%
df_clean_2 = df_clean_1.loc[valid_pay_1_mask,:].copy()

# %%
df_clean_2['PAY_1'] = df_clean_2['PAY_1'].astype('int64')
df_clean_2[['PAY_1', 'PAY_2']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26664 entries, 0 to 29999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PAY_1   26664 non-null  int64
#  1   PAY_2   26664 non-null  int64
# dtypes: int64(2)
# memory usage: 624.9 KB

# %%
df_clean_2['EDUCATION'].replace(to_replace=[0, 5, 6], value=4, inplace=True)
df_clean_2['EDUCATION'].value_counts()
# Out:
# 2    12458
# 1     9412
# 3     4380
# 4      414
# Name: EDUCATION, dtype: int64

# %%
df_clean_2['MARRIAGE'].replace(to_replace=0, value=3, inplace=True)
df_clean_2['MARRIAGE'].value_counts()
# Out:
# 2    14158
# 1    12172
# 3      334
# Name: MARRIAGE, dtype: int64

# %%
df_clean_2['EDUCATION_CAT'] = 'none'

# %%
df_clean_2[['EDUCATION', 'EDUCATION_CAT']].head(10)
# Out:
#    EDUCATION EDUCATION_CAT
# 0          2          none
# 1          2          none
# 2          2          none
# 3          2          none
# 4          2          none
# 5          1          none
# 6          1          none
# 7          2          none
# 8          3          none
# 9          3          none

# %%
cat_mapping = {
    1: "graduate school",
    2: "university",
    3: "high school",
    4: "others"
}

# %%
df_clean_2['EDUCATION_CAT'] = df_clean_2['EDUCATION'].map(cat_mapping)
df_clean_2[['EDUCATION', 'EDUCATION_CAT']].head(10)
# Out:
#    EDUCATION    EDUCATION_CAT
# 0          2       university
# 1          2       university
# 2          2       university
# 3          2       university
# 4          2       university
# 5          1  graduate school
# 6          1  graduate school
# 7          2       university
# 8          3      high school
# 9          3      high school

# %%
edu_ohe = pd.get_dummies(df_clean_2['EDUCATION_CAT'])
edu_ohe.head(10)
df_with_ohe = pd.concat([df_clean_2, edu_ohe], axis=1)
df_with_ohe[['EDUCATION_CAT', 'graduate school',
             'high school', 'university', 'others']].head(10)
df_with_ohe.to_csv('cleaned_data.csv', index=False)
